# %% [markdown]
# # Test post-processing analysis on synthetic data

# %%
from morphodynamics.plots.ui_outputs import OutputUI
# %matplotlib widget
# Out:
# <style>div.jupyter-widgets.widget-label {display: none;}</style>
# <style>.container { width:100% !important; }</style>

# %%
self = OutputUI('../synthetic/data/Results_ilastik')
self.load_data()

# %%
self.fig3

# %%
self.ev.interface

# %%
self.s.interface

# %%
self.c.interface
