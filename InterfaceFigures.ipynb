# %% [markdown]
# # Figures

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import dill
import os
from ArtifactGeneration import *
import FigureHelper
from Settings import Struct, load_settings
import matplotlib.pyplot as plt
# %matplotlib notebook
# %matplotlib
# Out:
# Using matplotlib backend: nbAgg

# %%
# dataset_name = 'Ellipse with triangle dynamics'
dataset_name = 'FRET_sensors + actinHistamineExpt2'
# dataset_name = 'TIAM_protrusion'
# dataset_name = 'TIAM_protrusion_full'
# dataset_name = 'FRET_sensors + actinHistamineExpt1_forPRES'
# dataset_name = 'FRET_sensors + actinPDGFExpt2_forPRES'
# dataset_name = 'Rac1_arhgap31_01_s2_forPRES'
# dataset_name = 'Rac1_arhgap31_02_s2_forPRES'

data, param = load_settings(dataset_name)

os.chdir('C:/Work/UniBE2/Results/Output 1')
res = dill.load(open(param.resultdir + "Results.pkl", "rb"))

# %% [markdown]
# ## Circularity

# %%
show_circularity(param, data, res, (8, 6))
# Out:
# <img src="data:image/png;base64,..." width="1600">
# <img src="data:image/png;base64,..." width="1600">
# <img src="data:image/png;base64,..." width="1600">

# %% [markdown]
# ## Edge overview

# %%
show_edge_overview(param, data, res, (8, 6))

# %% [markdown]
# ## Interactive edge (vectorial)

# %%
ev = EdgeVectorialSlow(param, data, res)
ev.create_interface()
# Out:
# IntSlider(value=0, continuous_update=False, description='Time', layout=Layout(width='100%'), max=158)
# <img src="data:image/png;base64,..." width="800">
# Output()

# %%
ev = EdgeVectorial(param, data, res)
ev.create_interface()

# %% [markdown]
# ## Interactive edge (rasterized)

# %%
er = EdgeRasterized(param, data, res)
er.create_interface()
# Out:
# RadioButtons(description='Mode:', index=1, options=('border', 'displacement', 'cumulative displacement', 'curv…
# RadioButtons(description='Normalization:', index=1, layout=Layout(width='max-content'), options=('global', 'fr…
# IntSlider(value=0, continuous_update=False, description='Time', layout=Layout(width='100%'), max=158)
# <img src="data:image/png;base64,..." width="800">
# Output()

# %% [markdown]
# ## Curvature

# %%
show_curvature(param, data, res, size=(8, 4.5))

# %%
curvature = Curvature(param, data, res)
curvature.create_interface()
# Out:
# FloatSlider(value=160.02474483848323, continuous_update=False, description='Range:', layout=Layout(width='100%…
# <img src="data:image/png;base64,..." width="800">
# Output()

# %% [markdown]
# ## Displacement

# %%
show_displacement(param, res, size=(8, 4.5))

# %% [markdown]
# ## Signals

# %%
s = Signals(param, data, res)
s.create_interface()
# Out:
# BoundedIntText(value=0, description='Channel:', max=4)
# BoundedIntText(value=0, description='Layer:', max=7)
# RadioButtons(description='Mode:', options=('Mean', 'Variance'), value='Mean')
# <img src="data:image/png;base64,..." width="800">
# Output()

# %% [markdown]
# ## Correlation

# %%
c = Correlation(param, data, res)
c.create_interface()
# Out:
# ...
# <img src="data:image/png;base64,..." width="800">
# IntRangeSlider(value=(0, 70), continuous_update=False, description='Window range', layout=Layout(width='100%')…
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# Output()

# %%
show_correlation_average(param, data, res, size=(8, 4.5))

# %% [markdown]
# # Batch export

# %%
be = BatchExport(param, data, res)
be.create_interface()
# Out:
# Checkbox(value=False, description='Circularity', indent=False)
# Checkbox(value=False, description='Edge overview', indent=False)
# Checkbox(value=False, description='Edge vectorial', indent=False)
# Checkbox(value=False, description='Edge rasterized', indent=False)
# Checkbox(value=False, description='Curvature', indent=False)
# Checkbox(value=False, description='Displacement', indent=False)
# Checkbox(value=False, description='Signals', indent=False)
# Checkbox(value=True, description='Correlation', indent=False)
# Checkbox(value=False, description='Fourier descriptors', indent=False)
# Button(description='Export figures', style=ButtonStyle())
# Output()
